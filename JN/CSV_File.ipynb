# %%
import pandas as pd

# %%
var = pd.read_csv("D:\\JN\\New.csv")
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
var.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
var.head(70)
# Out:
#     year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0   2011                    A  Agriculture, Forestry and Fishing          a_0
# 1   2011                    A  Agriculture, Forestry and Fishing          a_0
# 2   2011                    A  Agriculture, Forestry and Fishing          a_0
# 3   2011                    A  Agriculture, Forestry and Fishing          a_0
# 4   2011                    A  Agriculture, Forestry and Fishing          a_0
# ..   ...                  ...                                ...          ...
# 65  2011                    A  Agriculture, Forestry and Fishing       h_200+
# 66  2011                    A  Agriculture, Forestry and Fishing       h_200+
# 67  2011                    A  Agriculture, Forestry and Fishing       h_200+
# 68  2011                    A  Agriculture, Forestry and Fishing       h_200+
# 69  2011                    A  Agriculture, Forestry and Fishing       h_200+
#
# ...

# %%
var.tail()
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 17023  2021                  all       All Industries  j_Grand_Total
# 17024  2021                  all       All Industries  j_Grand_Total
# 17025  2021                  all       All Industries  j_Grand_Total
# 17026  2021                  all       All Industries  j_Grand_Total
# 17027  2021                  all       All Industries  j_Grand_Total
#
#                           variable    value               unit
# 17023                 Total income   757504  DOLLARS(millions)
# 17024            Total expenditure   654404  DOLLARS(millions)
# 17025  Operating profit before tax    85116  DOLLARS(millions)
# 17026                 Total assets  2512677  DOLLARS(millions)
# 17027        Fixed tangible assets   591351  DOLLARS(millions)

# %%
var.index
# Out:
# RangeIndex(start=0, stop=17028, step=1)

# %%
var.value
# Out:
# 0          46134
# 1              0
# 2            279
# 3           8187
# 4           8866
#           ...
# 17023     757504
# 17024     654404
# 17025      85116
# 17026    2512677
# 17027     591351
# Name: value, Length: 17028, dtype: object

# %%
var.columns
# Out:
# Index(['year', 'industry_code_ANZSIC', 'industry_name_ANZSIC', 'rme_size_grp',
#        'variable', 'value', 'unit'],
#       dtype='object')

# %%
var.describe()
# Out:
#                year
# count  17028.000000
# mean    2016.000000
# std        3.162371
# min     2011.000000
# 25%     2013.000000
# 50%     2016.000000
# 75%     2019.000000
# max     2021.000000

# %%
var[:2]
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                  variable  value   unit
# 0           Activity unit  46134  COUNT
# 1  Rolling mean employees      0  COUNT

# %%
var[79:103]
# Out:
#      year industry_code_ANZSIC               industry_name_ANZSIC  \
# 79   2011                    A  Agriculture, Forestry and Fishing
# 80   2011                    A  Agriculture, Forestry and Fishing
# 81   2011                    B                             Mining
# 82   2011                    B                             Mining
# 83   2011                    B                             Mining
# 84   2011                    B                             Mining
# 85   2011                    B                             Mining
# 86   2011                    B                             Mining
# 87   2011                    B                             Mining
# 88   2011                    B                             Mining
# 89   2011                    B                             Mining
# 90   2011                    B                             Mining
# 91   2011                    B                             Mining
# ...

# %%
var.to_numpy()
# Out:
# array([[2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Activity unit', '46134', 'COUNT'],
#        [2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Rolling mean employees', '0', 'COUNT'],
#        [2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Salaries and wages paid', '279', 'DOLLARS(millions)'],
#        ...,
#        [2021, 'all', 'All Industries', ...,
#         'Operating profit before tax', '85116', 'DOLLARS(millions)'],
#        [2021, 'all', 'All Industries', ..., 'Total assets', '2512677',
#         'DOLLARS(millions)'],
#        [2021, 'all', 'All Industries', ..., 'Fixed tangible assets',
#         '591351', 'DOLLARS(millions)']], dtype=object)

# %%
import numpy as np
v = np.asarray(var)
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17027  2021                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
v
# Out:
# array([[2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Activity unit', '46134', 'COUNT'],
#        [2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Rolling mean employees', '0', 'COUNT'],
#        [2011, 'A', 'Agriculture, Forestry and Fishing', ...,
#         'Salaries and wages paid', '279', 'DOLLARS(millions)'],
#        ...,
#        [2021, 'all', 'All Industries', ...,
#         'Operating profit before tax', '85116', 'DOLLARS(millions)'],
#        [2021, 'all', 'All Industries', ..., 'Total assets', '2512677',
#         'DOLLARS(millions)'],
#        [2021, 'all', 'All Industries', ..., 'Fixed tangible assets',
#         '591351', 'DOLLARS(millions)']], dtype=object)

# %%
var.sort_index(axis = 0,ascending = False)
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 17027  2021                  all                     All Industries
# 17026  2021                  all                     All Industries
# 17025  2021                  all                     All Industries
# 17024  2021                  all                     All Industries
# 17023  2021                  all                     All Industries
# ...     ...                  ...                                ...
# 4      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 0      2011                    A  Agriculture, Forestry and Fishing
#
#         rme_size_grp                                         variable  \
# 17027  j_Grand_Total                            Fixed tangible assets
# ...

# %%
var["industry_code_ANZSIC"] = "Janak"
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                Janak  Agriculture, Forestry and Fishing
# 1      2011                Janak  Agriculture, Forestry and Fishing
# 2      2011                Janak  Agriculture, Forestry and Fishing
# 3      2011                Janak  Agriculture, Forestry and Fishing
# 4      2011                Janak  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                Janak                     All Industries
# 17024  2021                Janak                     All Industries
# 17025  2021                Janak                     All Industries
# 17026  2021                Janak                     All Industries
# 17027  2021                Janak                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
var["industry_name_ANZIC"] = "Sapkota"
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                Janak  Agriculture, Forestry and Fishing
# 1      2011                Janak  Agriculture, Forestry and Fishing
# 2      2011                Janak  Agriculture, Forestry and Fishing
# 3      2011                Janak  Agriculture, Forestry and Fishing
# 4      2011                Janak  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                Janak                     All Industries
# 17024  2021                Janak                     All Industries
# 17025  2021                Janak                     All Industries
# 17026  2021                Janak                     All Industries
# 17027  2021                Janak                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                Janak  Agriculture, Forestry and Fishing
# 1      2011                Janak  Agriculture, Forestry and Fishing
# 2      2011                Janak  Agriculture, Forestry and Fishing
# 3      2011                Janak  Agriculture, Forestry and Fishing
# 4      2011                Janak  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                Janak                     All Industries
# 17024  2021                Janak                     All Industries
# 17025  2021                Janak                     All Industries
# 17026  2021                Janak                     All Industries
# 17027  2021                Janak                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
var.loc[0,"industry_name_ANZSIC"] = "Sapkota"
var
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                Janak                            Madhavi
# 1      2011                Janak  Agriculture, Forestry and Fishing
# 2      2011                Janak  Agriculture, Forestry and Fishing
# 3      2011                Janak  Agriculture, Forestry and Fishing
# 4      2011                Janak  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 17023  2021                Janak                     All Industries
# 17024  2021                Janak                     All Industries
# 17025  2021                Janak                     All Industries
# 17026  2021                Janak                     All Industries
# 17027  2021                Janak                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
var["industry_name_ANZSIC"] = "Khatam Manxe"
var
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 0      2011                Janak         Khatam Manxe            a_0
# 1      2011                Janak         Khatam Manxe            a_0
# 2      2011                Janak         Khatam Manxe            a_0
# 3      2011                Janak         Khatam Manxe            a_0
# 4      2011                Janak         Khatam Manxe            a_0
# ...     ...                  ...                  ...            ...
# 17023  2021                Janak         Khatam Manxe  j_Grand_Total
# 17024  2021                Janak         Khatam Manxe  j_Grand_Total
# 17025  2021                Janak         Khatam Manxe  j_Grand_Total
# 17026  2021                Janak         Khatam Manxe  j_Grand_Total
# 17027  2021                Janak         Khatam Manxe  j_Grand_Total
#
#                                               variable    value  \
# 0                                        Activity unit    46134
# ...

# %%
var.loc[[2,3],["year","variable"]]
# Out:
#    year                                         variable
# 2  2011                          Salaries and wages paid
# 3  2011  Sales, government funding, grants and subsidies

# %%
var.loc[:,["year","variable"]]
# Out:
#        year                                         variable
# 0      2011                                    Activity unit
# 1      2011                           Rolling mean employees
# 2      2011                          Salaries and wages paid
# 3      2011  Sales, government funding, grants and subsidies
# 4      2011                                     Total income
# ...     ...                                              ...
# 17023  2021                                     Total income
# 17024  2021                                Total expenditure
# 17025  2021                      Operating profit before tax
# 17026  2021                                     Total assets
# 17027  2021                            Fixed tangible assets
#
# [17028 rows x 2 columns]

# %%
var.iloc[0,1]
# Out:
# 'Janak'

# %%
var.drop(4,axis =0 )
# Out:
#        year industry_code_ANZSIC industry_name_ANZSIC   rme_size_grp  \
# 0      2011                Janak         Khatam Manxe            a_0
# 1      2011                Janak         Khatam Manxe            a_0
# 2      2011                Janak         Khatam Manxe            a_0
# 3      2011                Janak         Khatam Manxe            a_0
# 5      2011                Janak         Khatam Manxe            a_0
# ...     ...                  ...                  ...            ...
# 17023  2021                Janak         Khatam Manxe  j_Grand_Total
# 17024  2021                Janak         Khatam Manxe  j_Grand_Total
# 17025  2021                Janak         Khatam Manxe  j_Grand_Total
# 17026  2021                Janak         Khatam Manxe  j_Grand_Total
# 17027  2021                Janak         Khatam Manxe  j_Grand_Total
#
#                                               variable    value  \
# 0                                        Activity unit    46134
# ...
